# %%
# ingest the data

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\project-template\notebooks\data\gemstone.csv\cubic_zirconia.csv")

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %%
data.tail()
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 26962  26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963  26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964  26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965  26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966  26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
#        price
# 26962   5408
# 26963   1114
# 26964   1656
# 26965    682
# 26966   5166

# %%
data.sample(5)
# Out:
#           id  carat      cut color clarity  depth  table     x     y     z  \
# 22913  22914   0.56    Ideal     E     SI1   62.7   57.0  5.27  5.23  3.29
# 11052  11053   0.75  Premium     E     VS2   61.8   58.0  5.83  5.85  3.61
# 18715  18716   0.42    Ideal     F     VS1   61.0   57.0  4.87  4.84  2.96
# 21824  21825   1.11     Good     F     SI1   63.1   56.0  6.59  6.63  4.17
# 11990  11991   1.12    Ideal     E    VVS1   61.5   56.0  6.70  6.76  4.13
#
#        price
# 22913   1698
# 11052   3206
# 18715   1103
# 21824   5769
# 11990  14407

# %%
data.isnull().sum()
# Out:
# id           0
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       26967 non-null  int64
#  1   carat    26967 non-null  float64
#  2   cut      26967 non-null  object
#  3   color    26967 non-null  object
#  4   clarity  26967 non-null  object
#  5   depth    26270 non-null  float64
#  6   table    26967 non-null  float64
#  7   x        26967 non-null  float64
#  8   y        26967 non-null  float64
#  9   z        26967 non-null  float64
#  10  price    26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
data=data.drop(labels=["id"],axis=1)

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %%
data.duplicated().sum()
# Out:
# 34

# %%
data.shape
# Out:
# (26967, 10)

# %%
# cat vs num
categorical_columns=data.columns[data.dtypes=="object"]

# %%
numerical_columns=data.columns[data.dtypes!="object"]

# %%
data[categorical_columns].describe()
# Out:
#           cut  color clarity
# count   26967  26967   26967
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10816   5661    6571

# %%
data[categorical_columns]["cut"].value_counts()
# Out:
# cut
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data[categorical_columns]["color"].value_counts()
# Out:
# color
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: count, dtype: int64

# %%
data[categorical_columns]["clarity"].value_counts()
# Out:
# clarity
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: count, dtype: int64

# %%
data[numerical_columns].describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  26967.0     0.798375     0.477745    0.2    0.40     0.70     1.05
# depth  26270.0    61.745147     1.412860   50.8   61.00    61.80    62.50
# table  26967.0    57.456080     2.232068   49.0   56.00    57.00    59.00
# x      26967.0     5.729854     1.128516    0.0    4.71     5.69     6.55
# y      26967.0     5.733569     1.166058    0.0    4.71     5.71     6.54
# z      26967.0     3.538057     0.720624    0.0    2.90     3.52     4.04
# price  26967.0  3939.518115  4024.864666  326.0  945.00  2375.00  5360.00
#
#             max
# carat      4.50
# depth     73.60
# table     79.00
# x         10.23
# y         58.90
# z         31.80
# price  18818.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))


for col in numerical_columns:
    sns.histplot(data=data,x=col,kde=True)
    print("\n")
    plt.show()

# %%
sns.heatmap(data[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
# encoding  : we convert categorical features into numerical 
data["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
data["clarity"].unique()
# Out:
# array(['SI1', 'IF', 'VVS2', 'VS1', 'VVS1', 'VS2', 'SI2', 'I1'],
#       dtype=object)

# %%
data["color"].unique()
# Out:
# array(['E', 'G', 'F', 'D', 'H', 'J', 'I'], dtype=object)

# %%
## mapping 
# it is an ordinal encoding
cut_map={"Fair":1, "Good":2, "Very Good":3, "Premium":4,"Ideal":5}
clarity_map={"I1":1,"S12":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}
color_map={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
data["cut"]=data["cut"].map(cut_map)

# %%
data["clarity"]=data["clarity"].map(clarity_map)

# %%
data["color"]=data["color"].map(color_map)

# %%
data.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0.30    5      2      3.0   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    4      4      8.0   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90    3      2      6.0   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42    5      3      5.0   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31    5      3      7.0   60.4   59.0  4.35  4.43  2.65    779
